# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# ...

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
df[df['School Name'].str.contains('KIPP Academy')]
# Out:
#        School DBN                  School Name     School Level  \
# 19425      84X704  KIPP Academy Charter School  K-12 all grades
# 19426      84X704  KIPP Academy Charter School  K-12 all grades
# 19427      84X704  KIPP Academy Charter School  K-12 all grades
# 19428      84X704  KIPP Academy Charter School  K-12 all grades
# 19429      84X704  KIPP Academy Charter School  K-12 all grades
# ...           ...                          ...              ...
# 212297     84X704  KIPP Academy Charter School  K-12 all grades
# 212298     84X704  KIPP Academy Charter School  K-12 all grades
# 212299     84X704  KIPP Academy Charter School  K-12 all grades
# 212300     84X704  KIPP Academy Charter School  K-12 all grades
# 212301     84X704  KIPP Academy Charter School  K-12 all grades
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 19425         Algebra2/Trigonometry  2015            54       70.5
# ...

# %%
df2=df[df['School Name'].str.contains('KIPP Academy')]

# %%
df[df['School DBN'].str.contains('X')]
# Out:
#        School DBN                   School Name School Level  \
# 1125       10X504                  Kennedy Yabc  High school
# 3923       07X029  P.S./M.S. 029 Melrose School          K-8
# 3924       07X029  P.S./M.S. 029 Melrose School          K-8
# 3925       07X029  P.S./M.S. 029 Melrose School          K-8
# 3926       07X029  P.S./M.S. 029 Melrose School          K-8
# ...           ...                           ...          ...
# 212326     84X717          Icahn Charter School          K-8
# 212327     84X717          Icahn Charter School          K-8
# 212328     84X717          Icahn Charter School          K-8
# 212329     84X717          Icahn Charter School          K-8
# 212330     84X717          Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 1125            Common Core Algebra  2015             2          s
# 3923            Common Core Algebra  2015            29         65
# ...

# %%
df3=df[df['School DBN'].str.contains('X')]

# %%
df3.drop('84X704', axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-bcf5e3fc01fc> in <cell line: 1>()
# ----> 1 df3.drop('84X704', axis=0)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df[(df['School Name']== 'KIPP Academy Charter School')& (df['Regents Exam']=='Common Core Algebra')]
# Out:
#        School DBN                  School Name     School Level  \
# 19428      84X704  KIPP Academy Charter School  K-12 all grades
# 19429      84X704  KIPP Academy Charter School  K-12 all grades
# 19430      84X704  KIPP Academy Charter School  K-12 all grades
# 54150      84X704  KIPP Academy Charter School  K-12 all grades
# 54151      84X704  KIPP Academy Charter School  K-12 all grades
# 54152      84X704  KIPP Academy Charter School  K-12 all grades
# 54153      84X704  KIPP Academy Charter School  K-12 all grades
# 54154      84X704  KIPP Academy Charter School  K-12 all grades
# 54155      84X704  KIPP Academy Charter School  K-12 all grades
# 102768     84X704  KIPP Academy Charter School  K-12 all grades
# 102769     84X704  KIPP Academy Charter School  K-12 all grades
# 102770     84X704  KIPP Academy Charter School  K-12 all grades
# 102771     84X704  KIPP Academy Charter School  K-12 all grades
# 102772     84X704  KIPP Academy Charter School  K-12 all grades
# ...

# %%
df2[df2['Regents Exam']=='Common Core Algebra']
# Out:
#        School DBN                  School Name     School Level  \
# 19428      84X704  KIPP Academy Charter School  K-12 all grades
# 19429      84X704  KIPP Academy Charter School  K-12 all grades
# 19430      84X704  KIPP Academy Charter School  K-12 all grades
# 54150      84X704  KIPP Academy Charter School  K-12 all grades
# 54151      84X704  KIPP Academy Charter School  K-12 all grades
# 54152      84X704  KIPP Academy Charter School  K-12 all grades
# 54153      84X704  KIPP Academy Charter School  K-12 all grades
# 54154      84X704  KIPP Academy Charter School  K-12 all grades
# 54155      84X704  KIPP Academy Charter School  K-12 all grades
# 102768     84X704  KIPP Academy Charter School  K-12 all grades
# 102769     84X704  KIPP Academy Charter School  K-12 all grades
# 102770     84X704  KIPP Academy Charter School  K-12 all grades
# 102771     84X704  KIPP Academy Charter School  K-12 all grades
# 102772     84X704  KIPP Academy Charter School  K-12 all grades
# ...

# %%
KIPPCCA=df2[df2['Regents Exam']=='Common Core Algebra']

# %%
df3[df3['Regents Exam']=='Common Core Algebra']
# Out:
#        School DBN                               School Name School Level  \
# 1125       10X504                              Kennedy Yabc  High school
# 3923       07X029              P.S./M.S. 029 Melrose School          K-8
# 3924       07X029              P.S./M.S. 029 Melrose School          K-8
# 3925       07X029              P.S./M.S. 029 Melrose School          K-8
# 3929       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# ...           ...                                       ...          ...
# 212319     84X717                      Icahn Charter School          K-8
# 212320     84X717                      Icahn Charter School          K-8
# 212321     84X717                      Icahn Charter School          K-8
# 212322     84X717                      Icahn Charter School          K-8
# 212323     84X717                      Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# ...

# %%
df[(df['School Name']== 'P.S./M.S. 031 The William Lloyd Garrison')& (df['Regents Exam']=='Common Core Algebra')]
# Out:
#        School DBN                               School Name School Level  \
# 3929       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 3930       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 3931       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26606      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26607      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26608      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26609      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64189      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64190      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64192      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64193      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64194      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# ...

# %%
PS31CCA=df[(df['School Name']== 'P.S./M.S. 031 The William Lloyd Garrison')& (df['Regents Exam']=='Common Core Algebra')]

# %%
KIPPCCA.describe()
# Out:
#               Year  Total Tested
# count    32.000000     32.000000
# mean   2016.031250     30.937500
# std       0.822442     22.969738
# min    2015.000000      1.000000
# 25%    2015.000000     15.750000
# 50%    2016.000000     26.000000
# 75%    2017.000000     44.000000
# max    2017.000000     93.000000

# %%
KIPPCCA["Mean Score"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1629         try:
# -> 1630             x = float(x)
#    1631         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '67.575.976.969.46476.672.580.267.4s68.7ss76.2ss77s65.469.776.175.677.176.869.965s76.2ss76.9s'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1633             try:
# -> 1634                 x = complex(x)
#    1635             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
PS31CCA.describe()
# Out:
#               Year  Total Tested
# count    29.000000     29.000000
# mean   2015.965517      6.551724
# std       0.823007      4.508612
# min    2015.000000      1.000000
# 25%    2015.000000      3.000000
# 50%    2016.000000      6.000000
# 75%    2017.000000     10.000000
# max    2017.000000     15.000000

# %%
KIPPCCA.dropna()
# Out:
#        School DBN                  School Name     School Level  \
# 19428      84X704  KIPP Academy Charter School  K-12 all grades
# 19429      84X704  KIPP Academy Charter School  K-12 all grades
# 19430      84X704  KIPP Academy Charter School  K-12 all grades
# 54150      84X704  KIPP Academy Charter School  K-12 all grades
# 54151      84X704  KIPP Academy Charter School  K-12 all grades
# 54152      84X704  KIPP Academy Charter School  K-12 all grades
# 54153      84X704  KIPP Academy Charter School  K-12 all grades
# 54154      84X704  KIPP Academy Charter School  K-12 all grades
# 54155      84X704  KIPP Academy Charter School  K-12 all grades
# 102768     84X704  KIPP Academy Charter School  K-12 all grades
# 102769     84X704  KIPP Academy Charter School  K-12 all grades
# 102770     84X704  KIPP Academy Charter School  K-12 all grades
# 102771     84X704  KIPP Academy Charter School  K-12 all grades
# 102772     84X704  KIPP Academy Charter School  K-12 all grades
# ...

# %%
PS31CCA.dropna()
# Out:
#        School DBN                               School Name School Level  \
# 3929       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 3930       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 3931       07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26606      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26607      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26608      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 26609      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64189      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64190      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64192      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64193      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# 64194      07X031  P.S./M.S. 031 The William Lloyd Garrison          K-8
# ...

# %% [markdown]
# How do I code for a side by side bar graph that shows the mean scores of the Common Core Algebra Regents for KIPP Academy and PS 31 in 2015, 2016, and 2017?
#
# **X axis**=Year and
# **Y axis**=Percentage

# %%
KIPPCCA.plot.scatter(x='Year', y='Mean Score')
# Out:
# <Axes: xlabel='Year', ylabel='Mean Score'>

# %%
PS31CCA.plot.scatter(x='Year', y='Mean Score')
# Out:
# <Axes: xlabel='Year', ylabel='Mean Score'>

# %% [markdown]
# For my project, my goal is to compare the Common Core Algebra regents scores for KIPP Academy Charter School and P.S 31. I chose these specific schools because I attended KIPP Academy and I remember my math teacher being exceptional. Also, P.S 31 and KIPP Academy are actually in the exact smae building. Thus, I thought it would be interesting to see how similar or how different two schools that are two floors away from each other would perform on this regents exam. I did not quite get to visualize the data how I hoped; I wanted to do a multiple bar plot that could have the year on the x-axis and the mean score on the y-axis but I had difficulty visulaizing that. In the end, I was able to at least isolate KIPP Academy scores, P.S 31 scores, and then make a scatter plot for the mean scores. At a first glance, I see that the students of P.S 31 did not take the Common Core Algebra regents as much as KIPP Academy did. KIPP and P.S 31 have about the same averages, with KIPP outperforming
# P.S 31 a couple of times where the mean score was 80 or above. KIPP also outperforms P.S 31 in the amount of students that are actually ready to even take the exam in the first place. This says to me that my math teacher was exceptional indeed.
